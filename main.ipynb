# %%
from pandas import plotting
from pytrends.request import TrendReq
import matplotlib.pyplot as plt

# %%
plt.style.use('bmh')
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %%
#input on term
term = input('\nDigite o term desejado:')
print(term)
# Out:
# kindle

# %%
# connect to google
pytrends = TrendReq(hl='pt-BR', tz=360)
# keywords to search for
pytrends.build_payload(kw_list=[term])

# %%
# dataframe
time_df = pytrends.interest_over_time()
print(time_df)
# Out:
#             kindle isPartial
# date
# 2016-09-04      62     False
# 2016-09-11      59     False
# 2016-09-18      54     False
# 2016-09-25      53     False
# 2016-10-02      55     False
# ...            ...       ...
# 2021-07-25      42     False
# 2021-08-01      43     False
# 2021-08-08      44     False
# 2021-08-15      46     False
# 2021-08-22      44      True
#
# [260 rows x 2 columns]

# %%
time_df.columns
# Out:
# Index(['kindle', 'isPartial'], dtype='object')

# %%
# creating graph
fig, ax = plt.subplots(figsize=(12, 6))
time_df[term].plot(color='purple')
# adding title and labels
plt.title('Total de pesquisas do Google  por "'+ term +'"', fontweight='bold')
plt.xlabel('Ano')
plt.ylabel('Total Pesquisa')
# Out:
# Text(0, 0.5, 'Total Pesquisa')
